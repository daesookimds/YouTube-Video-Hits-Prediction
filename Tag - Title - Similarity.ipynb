# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %matplotlib inline

# %% [markdown]
# ### Data Load

# %%
train = pd.read_csv("train.csv")

print(train.shape)
train.head()
# Out:
# (10024, 13)
#   category   comments  crawl_date dislike  like play_time subscribers  \
# 0       게임  댓글 4,919개  2018.08.23     277  1.3만      0:14        151만
# 1       게임  댓글 4,964개  2018.08.23     278  8.7천      0:15        236만
# 2       게임  댓글 5,262개  2018.08.23     561  2.3만      6:47        246만
# 3       게임  댓글 1,823개  2018.08.23     404  1.1천     13:00         23만
# 4       게임  댓글 1,159개  2018.08.23      36  3.4천     10:00         47만
#
#                                                  tag  \
# 0  ['마인크래프트', 'Minecraft', '샌드박스 네트워크', '샌드박스', '...
# 1  ['도티', '도티 마피아', '도티 머더', '마피아 머더', 'mafia', '...
# 2  ['보겸', '보겸TV', 'bokyem', '도티', '롤', '오버워치', '원...
# 3  ['게임', '위닝', '위닝일레븐', '축구게임', '말이야와 게임들 축구게임',...
# 4  ['카베', '모바일베그', '배그M', '카카오베그', '연다', '배틀그라운드'...
#
#                                                title  \
# 0       마크판 거지키우기 업그레이드 *크리에이터* 키우기! - 마인크래프트 - [잠뜰]
# 1                 직업 머더 "곤충"능력 특집 (부제: 파브르와 저승벌레 팡수)
# 2                        14번의”아디오스” ㄷ1지고싶으면 들이대봐 드루와
# 3  그때 눈물의 축구 게임 복수전! 과연 미니 고수 말이야 이길 수 있을까? (꿀잼) ...
# 4  초보자도 여포로 만들어 줄 수 있는 총 조합! 제가 알려드리죠 ㅋㅋ (배틀그라운드-...
#
#                                          top_comment        upload_date  \
# 0  그동안 여러분이 잠뜰TV에서 가장 재밌게 본 영상은?!\n댓글에 많이 남겨주시고 좋...  게시일: 2018. 8. 17.
# 1  다음 컨셉은 아이스 크림 어떨까요?예를 들면스크류바:술래가 한 대 치면 술래를 5초...  게시일: 2018. 8. 20.
# 2  모듀 ㅂㅇㄹ ^_^* \nㅋㅋㅋ 역대 최대킬 ㅋㅋㅋ\n고마워 ^_^+ 가조쿠들 ㅋㅋ...  게시일: 2018. 8. 18.
# 3  사랑하는 말랑이 여러분! 다음에는 말이야, 로기, 미니 축구팀을 댓글로 남겨주세요....  게시일: 2018. 8. 18.
# 4  크흠...저런 총이 있어도 난 여포가 아니라 쥐포가 될것 같은데...\niny070...  게시일: 2018. 8. 21.
#
#                                                  url         views
# 0  https://www.youtube.com/watch?v=azoDJNPRU7s&li...  조회수 579,949회
# 1  https://www.youtube.com/watch?v=-BnUuHgUK5Q&li...  조회수 451,676회
# 2  https://www.youtube.com/watch?v=v0rDCGLcnpU&li...  조회수 955,578회
# 3  https://www.youtube.com/watch?v=cK8Z2fz0iUI&li...  조회수 191,211회
# 4  https://www.youtube.com/watch?v=bBbHq5sMqP0&li...  조회수 162,253회

# %% [markdown]
# ### Upload_date
# - 게시년, 월, 일

# %%
ls=list(train["upload_date"])

# %%
del_list = []
for i, s in enumerate(ls):
    if "시간시간" in s:
        print(s)
        del_list.append(i)
del_list
# Out:
# 실시간 스트림: 14시간시간 전
# 실시간 스트림: 10시간시간 전
# 실시간 스트림: 12시간시간 전
# 실시간 스트림: 21시간시간 전
# 실시간 스트림: 18시간시간 전
# 실시간 스트림: 21시간시간 전
# 실시간 스트림: 17시간시간 전
# 실시간 스트림: 15시간시간 전
# 실시간 스트림: 18시간시간 전
# 실시간 스트림: 3시간시간 전
# 실시간 스트림: 22시간시간 전
# 실시간 스트림: 23시간시간 전
# 실시간 스트림: 14시간시간 전
# 실시간 스트림: 11시간시간 전
# 실시간 스트림: 10시간시간 전
# 실시간 스트림: 10시간시간 전
# 실시간 스트림: 22시간시간 전
# 실시간 스트림: 11시간시간 전
# 실시간 스트림: 23시간시간 전
# 실시간 스트림: 9시간시간 전
# 실시간 스트림: 21시간시간 전
# 실시간 스트림: 21시간시간 전
# 실시간 스트림: 22시간시간 전
# [3197,
#  3251,
#  3263,
#  4879,
#  4885,
#  4906,
#  4923,
#  4928,
#  5279,
#  6647,
#  7368,
#  7390,
#  7402,
#  7411,
#  8134,
#  8135,
#  8393,
#  8425,
#  8531,
#  8536,
#  8557,
#  8559,
#  8653]

# %%
train = train.drop(del_list)
train.shape
# Out:
# (10001, 13)

# %%
train = train.reset_index(drop=True)

# %%
s = '게시일: 2014. 2. 26.'

# %%
s[5:-1].replace(" ","").split(".")
# Out:
# ['2014', '2', '26']

# %%
def upload_date_clear_year(date):
    if len(date) > 20:
        return int(date[14:-1].replace(" ","").split(".")[0])
    else:
        return int(date[5:-1].replace(" ","").split(".")[0])

def upload_date_clear_month(date):
    if len(date) > 20:
        return int(date[14:-1].replace(" ","").split(".")[1])
    else:
        return int(date[5:-1].replace(" ","").split(".")[1])

def upload_date_clear_day(date):
    if len(date) > 20:
        return int(date[14:-1].replace(" ","").split(".")[2])
    else:
        return int(date[5:-1].replace(" ","").split(".")[2])

# %%
train["upload_date_year"] = train["upload_date"].apply(upload_date_clear_year)
train["upload_date_month"] = train["upload_date"].apply(upload_date_clear_month)
train["upload_date_day"] = train["upload_date"].apply(upload_date_clear_day)

# %%
train[["upload_date_year", "upload_date_month", "upload_date_day"]].head()
# Out:
#    upload_date_year  upload_date_month  upload_date_day
# 0              2018                  8               17
# 1              2018                  8               20
# 2              2018                  8               18
# 3              2018                  8               18
# 4              2018                  8               21

# %% [markdown]
# ### Crawl_date

# %%
s = '2014.2.26'

# %%
int(s.split(".")[0])
# Out:
# 2014

# %%
def crawl_data_clear_year(date):
    return int(date.split(".")[0])

def crawl_data_clear_month(date):
    return int(date.split(".")[1])

def crawl_data_clear_day(date):
    return int(date.split(".")[2])

# %%
train["crawl_date_year"] = train["crawl_date"].apply(crawl_data_clear_year)
train["crawl_date_month"] = train["crawl_date"].apply(crawl_data_clear_month)
train["crawl_date_day"] = train["crawl_date"].apply(crawl_data_clear_day)

# %%
train[["crawl_date_year", "crawl_date_month", "crawl_date_day"]].head()
# Out:
#    crawl_date_year  crawl_date_month  crawl_date_day
# 0             2018                 8              23
# 1             2018                 8              23
# 2             2018                 8              23
# 3             2018                 8              23
# 4             2018                 8              23

# %% [markdown]
# ### Uploaded days

# %%
from datetime import date

for idx in tqdm(range(0, len(train))):
    d0 = date(train["upload_date_year"].loc[idx], train["upload_date_month"].loc[idx], train["upload_date_day"].loc[idx])
    d1 = date(train["crawl_date_year"].loc[idx], train["crawl_date_month"].loc[idx], train["crawl_date_day"].loc[idx])
    train.loc[idx, "uploaded_days"] = (d1 - d0).days + 1
# Out:
# 100%|██████████| 10001/10001 [00:07<00:00, 1333.97it/s]

# %%
train[["uploaded_days"]].head()
# Out:
#    uploaded_days
# 0            7.0
# 1            4.0
# 2            6.0
# 3            6.0
# 4            3.0

# %% [markdown]
# ### Views
# - 조회수 ( 일평균 조회수를 target 값으로 사용 )
# - 예측할 target

# %%
def views_clear(view):
    if view == '조회수 없음':
        return 0
    else:
        return int(view[4:-1].replace(",",""))

# %%
train["views"] = train["views"].apply(views_clear)

# %%
train["views"].head()
# Out:
# 0    579949
# 1    451676
# 2    955578
# 3    191211
# 4    162253
# Name: views, dtype: int64

# %%
train["views"] = train["views"] / train["uploaded_days"]

# %%
train["views"].head()
# Out:
# 0     82849.857143
# 1    112919.000000
# 2    159263.000000
# 3     31868.500000
# 4     54084.333333
# Name: views, dtype: float64

# %% [markdown]
# ### Number of Tag

# %%
import ast

def tag_list(x):
    return ast.literal_eval(x)

def tag_count(x):
    return len(x)

# %%
train["tag_list"] = train["tag"].apply(tag_list)

# %%
train["tag_count"] = train["tag"].apply(tag_count)

# %%
train[["tag_list", "tag_count"]].head()
# Out:
#                                             tag_list  tag_count
# 0  [마인크래프트, Minecraft, 샌드박스 네트워크, 샌드박스, 샌박, Sandb...        512
# 1  [도티, 도티 마피아, 도티 머더, 마피아 머더, mafia, 마인크래프트 머더, ...        293
# 2  [보겸, 보겸TV, bokyem, 도티, 롤, 오버워치, 원피스, 리그오브레전드, ...        167
# 3  [게임, 위닝, 위닝일레븐, 축구게임, 말이야와 게임들 축구게임, 말이야와 게임들 ...        533
# 4  [카베, 모바일베그, 배그M, 카카오베그, 연다, 배틀그라운드, PSS, APL, ...        461

# %% [markdown]
# ### title and tag similarity

# %%
train[["title", "tag", "tag_list"]].head()
# Out:
#                                                title  \
# 0       마크판 거지키우기 업그레이드 *크리에이터* 키우기! - 마인크래프트 - [잠뜰]
# 1                 직업 머더 "곤충"능력 특집 (부제: 파브르와 저승벌레 팡수)
# 2                        14번의”아디오스” ㄷ1지고싶으면 들이대봐 드루와
# 3  그때 눈물의 축구 게임 복수전! 과연 미니 고수 말이야 이길 수 있을까? (꿀잼) ...
# 4  초보자도 여포로 만들어 줄 수 있는 총 조합! 제가 알려드리죠 ㅋㅋ (배틀그라운드-...
#
#                                                  tag  \
# 0  ['마인크래프트', 'Minecraft', '샌드박스 네트워크', '샌드박스', '...
# 1  ['도티', '도티 마피아', '도티 머더', '마피아 머더', 'mafia', '...
# 2  ['보겸', '보겸TV', 'bokyem', '도티', '롤', '오버워치', '원...
# 3  ['게임', '위닝', '위닝일레븐', '축구게임', '말이야와 게임들 축구게임',...
# 4  ['카베', '모바일베그', '배그M', '카카오베그', '연다', '배틀그라운드'...
#
#                                             tag_list
# 0  [마인크래프트, Minecraft, 샌드박스 네트워크, 샌드박스, 샌박, Sandb...
# 1  [도티, 도티 마피아, 도티 머더, 마피아 머더, mafia, 마인크래프트 머더, ...
# 2  [보겸, 보겸TV, bokyem, 도티, 롤, 오버워치, 원피스, 리그오브레전드, ...
# 3  [게임, 위닝, 위닝일레븐, 축구게임, 말이야와 게임들 축구게임, 말이야와 게임들 ...
# 4  [카베, 모바일베그, 배그M, 카카오베그, 연다, 배틀그라운드, PSS, APL, ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### 태그와 타이틀간 같은 단어가 몇개 있는가?

# %%
vect = CountVectorizer()

# %%
vect.fit(train["tag_list"].loc[0])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vect.transform([train["title"].loc[0]]).toarray().sum()
# Out:
# 4

# %%
vect.fit(train["tag_list"].loc[1])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vect.transform([train["title"].loc[1]]).toarray().sum()
# Out:
# 1

# %% [markdown]
# ### 태그와 타이틀 간 코사인 유사도

# %%
vect2 = CountVectorizer()

# %%
vect2.fit(train["tag"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vect2.vocabulary_
# Out:
# {'마인크래프트': 25634,
#  'minecraft': 9369,
#  '샌드박스': 30901,
#  '네트워크': 21671,
#  '샌박': 30912,
#  'sandbox': 12057,
#  'network': 9976,
#  '잠뜰': 40552,
#  'sleepground': 12705,
#  '도티': 23445,
#  'ddotty': 4011,
#  '수현': 32380,
#  '칠각별': 44057,
#  '각별': 17422,
#  '쵸쵸우': 43730,
#  '쵸우': 43728,
#  '코아': 44632,
#  '연다': 36414,
#  '라더': 24238,
#  '포로': 46618,
#  '모장': 26479,
#  'mojang': 9524,
#  '모드': 26407,
#  '마크': 25677,
#  '쇼케이스': 32173,
#  'mod': 9510,
#  'showcase': 12500,
#  '어드벤쳐': 35482,
#  '커스텀': 44395,
#  'npc': 10196,
#  '원커맨드': 38132,
#  '커맨드': 44378,
#  '양띵': 35319,
#  '악어': 34703,
#  '컨텐츠': 44437,
#  '콘텐츠': 44686,
#  '미니게임': 27049,
#  '거지키우기': 17986,
#  '크리에이터': 44931,
#  '패러디': 46265,
#  '마피아': 25711,
#  '머더': 26043,
#  'mafia': 8872,
#  'ehxl': 4721,
#  'murder': 9730,
#  '탈출맵': 45285,
#  '점프맵': 41175,
#  '마크도티': 25678,
#  '경찰과도둑': 18363,
#  '도도한친구들': 23334,
#  '우리이야기': 37791,
#  '공룡': 18812,
#  '보겸': 28822,
#  '보겸tv': 28823,
#  'bokyem': 2397,
#  '오버워치': 37098,
#  '원피스': 38144,
#  '리그오브레전드': 25173,
#  '먹방': 26073,
#  '클로얄': 45009,
#  '배그': 28193,
#  'battleground': 1975,
#  'mukbang': 9709,
#  'hikakin': 6531,
#  'hajime': 6246,
#  'pewdiepie': 10806,
#  'jfla': 7395,
#  'korean': 8090,
#  'kpop': 8126,
#  '게임': 18137,
#  '위닝': 38256,
#  '위닝일레븐': 38257,
#  '축구게임': 43809,
#  '말이야와': 25825,
#  '게임들': 18140,
#  '축구': 43802,
#  'game': 5678,
#  'games': 5684,
#  '말이야': 25824,
#  '끼야': 21038,
#  '인기게임': 39754,
#  '추천게임': 43783,
#  '2019': 464,
#  '아시안': 34390,
#  '게임영상': 18146,
#  '게임플레이': 18158,
#  '말이야와게임들': 25826,
#  '친구들': 44032,
#  '아이들': 34461,
#  '세상의': 31626,
#  '모든': 26415,
#  '재미': 40782,
#  '마리디아': 25465,
#  '놀이': 21900,
#  '플래시게임': 47087,
#  '플래시': 47086,
#  '모바일게임': 26441,
#  '모바일': 26440,
#  '콘솔게임': 44677,
#  '비디오게임': 29842,
#  '피씨게임': 47187,
#  'pc게임': 10701,
#  'mobile': 9502,
#  'flash': 5388,
#  'console': 3516,
#  'pc': 10700,
#  'kids': 7897,
#  'children': 3129,
#  'family': 5156,
#  'fun': 5607,
#  'play': 10947,
#  'mariandgames': 8987,
#  'mariandfriends': 8986,
#  'mariandkids': 8988,
#  'maridea': 8989,
#  '카베': 44129,
#  '모바일베그': 26446,
#  '배그m': 28194,
#  '카카오베그': 44179,
#  '배틀그라운드': 28288,
#  'pss': 11215,
#  'apl': 1535,
#  'tpp': 14039,
#  'fpp': 5507,
#  '연두색판다': 36417,
#  '김블루': 20242,
#  'playerunknown': 10952,
#  'sbattlegrounds': 12124,
#  'pubg': 11229,
#  'battlegrounds': 1976,
#  '뜨뜨': 24220,
#  '더헬': 23104,
#  '군림보': 19424,
#  '눈쟁이': 22052,
#  '사녹': 30343,
#  'sahnok': 12018,
#  'm416': 8830,
#  'scar': 12143,
#  'akm': 1305,
#  'slr': 12727,
#  'ump': 14428,
#  'vector': 14591,
#  '에이케이': 35901,
#  '스카': 32731,
#  '스르륵': 32633,
#  '엠포': 36086,
#  '브스스': 29681,
#  'vss': 14786,
#  '에땁': 35769,
#  'awm': 1766,
#  'm24': 8828,
#  '소음기': 31902,
#  '엠이사': 36076,
#  '프라이팬': 46913,
#  '후라이팬': 49147,
#  '에란겔': 35773,
#  '미라마': 27124,
#  '미라도': 27123,
#  '다시아': 22306,
#  '철토마': 43263,
#  '지프': 42592,
#  '우아즈': 37819,
#  '우아지': 37820,
#  '우승': 37816,
#  '치킨': 44011,
#  '램램': 24463,
#  '상황극': 30835,
#  '자전거': 40445,
#  '레이스': 24721,
#  '오토바이': 37231,
#  '오토마우스': 37230,
#  '공포게임': 18913,
#  '블루스택': 29773,
#  '노가다게임': 21690,
#  '썩쏘': 34049,
#  '공갈': 18760,
#  '태경': 45317,
#  '마일드': 25638,
#  '핑맨': 47332,
#  '개리': 17814,
#  '멋사': 26117,
#  '옴므': 37405,
#  '서넹': 31070,
#  '미소': 27179,
#  '대정령': 22831,
#  '머독': 26045,
#  '로이조': 24938,
#  '철구': 43243,
#  '최군': 43571,
#  '대도서관': 22732,
#  '가이코': 17371,
#  '너불': 21587,
#  '중력': 42297,
#  'yt애플': 15461,
#  '바위골렘': 27581,
#  '4시': 789,
#  '쵸코': 43731,
#  '홍방장': 48830,
#  '풍월량': 46892,
#  '희바': 49371,
#  '김왼팔': 20390,
#  '진호': 42741,
#  '369랑께': 650,
#  '운학': 37926,
#  '메이비': 26175,
#  '허팝': 48372,
#  'thediamondminecart': 13759,
#  '비콘': 29979,
#  '빅민': 30024,
#  '마플': 25709,
#  '마인애플': 25630,
#  '카운터': 44150,
#  '운터운터': 37922,
#  '메이플': 26214,
#  '메이플스토리': 26215,
#  '즐겜': 42352,
#  '표림': 46799,
#  '초보자': 43470,
#  '200': 387,
#  '200레벨': 402,
#  '구만렙': 19210,
#  '트롤': 45824,
#  '평범': 46540,
#  '혁신': 48513,
#  '운터': 37921,
#  '운터운터카운터': 37923,
#  'fgcounter': 5279,
#  'minedapple': 9370,
#  '하루': 47402,
#  '운터의': 37924,
#  '마플의': 25710,
#  '아이템': 34534,
#  '비하인드': 30013,
#  '꾸몽': 20778,
#  '꾸몽월드': 20779,
#  '생방': 30958,
#  '녹방': 21860,
#  '하이라이트': 47488,
#  '영상': 36650,
#  '방송': 28101,
#  '스팀': 33037,
#  '신작': 33703,
#  '김영태': 20379,
#  'walkthrough': 14845,
#  '워크쓰루': 38040,
#  '워크스루': 38039,
#  'let': 8471,
#  '렛츠플레이': 24812,
#  'steam': 13133,
#  'twitch': 14328,
#  '트위치': 45861,
#  '한량': 47788,
#  '동네': 23588,
#  '나라': 21072,
#  '지구본': 42390,
#  '지도': 42434,
#  '구글지도': 19175,
#  '구글': 19172,
#  'google': 5971,
#  '네이버지도': 21654,
#  '네이버': 21649,
#  'ok': 10336,
#  '세계여행': 31558,
#  '세계': 31546,
#  '여행': 36331,
#  '어느': 35474,
#  '맞히는': 25890,
#  '거리뷰': 17928,
#  '길찾기': 20061,
#  '찾기': 43082,
#  '어플': 35597,
#  '의지의': 38982,
#  '히어로': 49403,
#  '뽁구': 30231,
#  'willhero': 15046,
#  'will': 15043,
#  'hero': 6490,
#  '2000': 388,
#  '버그판': 28427,
#  '링크': 25423,
#  '공유': 18868,
#  '레드': 24633,
#  '드래곤': 23837,
#  '고수': 18555,
#  '1000': 37,
#  '초고수': 43421,
#  '공략': 18810,
#  '의지의히어로': 38983,
#  '잘하는법': 40549,
#  '업데이트': 35693,
#  '버그': 28426,
#  '레드드래곤': 24634,
#  '악마의': 34696,
#  '악마': 34694,
#  '귀신': 19567,
#  '추천': 43781,
#  '리뷰': 25248,
#  '순위': 32416,
#  '멍뭉이': 26124,
#  '대전쟁': 22825,
#  '멍뭉이대전쟁': 26125,
#  '다운': 22314,
#  '다운로드': 22316,
#  '하는법': 47373,
#  '파란돌': 46033,
#  '냥코대전쟁': 21569,
#  '통조림': 45646,
#  '코드': 44550,
#  '광란': 19035,
#  '3장': 699,
#  '냥코': 21568,
#  '울트라슈퍼레어': 37956,
#  '수탉': 32356,
#  '수탉tv': 32357,
#  '공포': 18912,
#  '실황': 33898,
#  '인형': 39973,
#  '무서운': 26702,
#  '루태': 25102,
#  '삼식': 30746,
#  '눈꽃': 22026,
#  '후추': 49171,
#  '다주': 22396,
#  '콩콩': 44745,
#  'yd': 15296,
#  '미니': 27044,
#  '설정': 31403,
#  '양띵tv': 35320,
#  '동영상': 23667,
#  '몬스터': 26561,
#  '모스리': 26459,
#  '스토리': 32961,
#  'tv': 14271,
#  'video': 14656,
#  'culture': 3754,
#  '기능': 19896,
#  '꿀팁': 20997,
#  '야생': 35243,
#  '목장': 26542,
#  '초거대': 43413,
#  '천양': 43216,
#  'jurassic': 7647,
#  'park': 10613,
#  'world': 15165,
#  'fallen': 5146,
#  'kingdom': 7941,
#  '인도미누스': 39778,
#  '렉스': 24791,
#  '인도랩터': 39776,
#  'indominus': 7024,
#  'rex': 11658,
#  'indoraptor': 7028,
#  '쥬라기공원': 42338,
#  '쥬라기월드': 42339,
#  'the': 13747,
#  '폴른킹덤': 46779,
#  '에볼루션': 35807,
#  'vip': 14697,
#  '겜스터': 18166,
#  '인도미누스렉스': 39779,
#  '티라노사우루스': 45931,
#  '공룡게임': 18813,
#  '테드': 45462,
#  '테드tv': 45463,
#  'ted': 13652,
#  'tedtv': 13655,
#  'clash': 3288,
#  'royale': 11893,
#  '클래시로얄': 44963,
#  '미리보기': 27152,
#  '스닉픽': 32628,
#  'update': 14507,
#  'sneak': 12781,
#  'peek': 10721,
#  'legendary': 8431,
#  'chest': 3113,
#  '전설': 41009,
#  '상자': 30816,
#  'new': 9986,
#  'cards': 2842,
#  '클랜전': 44979,
#  'pong': 11022,
#  'skeleton': 12649,
#  'barrel': 1934,
#  '킹스컵': 45147,
#  'sugical': 13304,
#  'goblin': 5922,
#  'tnt': 13925,
#  'ghost': 5822,
#  'barbarian': 1923,
#  'gameplay': 5682,
#  '클로': 45007,
#  'clan': 3279,
#  'war': 14867,
#  '로얄훈련병': 24924,
#  '로얄': 24921,
#  '훈련병': 49189,
#  '멜리': 26279,
#  '파쿠르': 46155,
#  '럭키블럭': 24564,
#  '헝거게임': 48397,
#  'ark': 1601,
#  'aberration': 1090,
#  '아크': 34621,
#  '아크서바이벌이볼브드': 34626,
#  '에버레이션': 35802,
#  '재넌': 40774,
#  'gta': 6121,
#  'gta5': 6122,
#  '카카오': 44174,
#  '다음': 22326,
#  '스타크래프트': 32899,
#  '윤루트': 38719,
#  '에버모어': 35803,
#  '하얀눈길': 47454,
#  '딩셉션': 24090,
#  '페이커': 46465,
#  '아프리카tv': 34662,
#  '유튜브': 38625,
#  '4entro': 754,
#  '벤츠': 28704,
#  '대휘': 22935,
#  '블랙워크': 29721,
#  '실프': 33884,
#  '주안': 42110,
#  '스크림': 32811,
#  '지스타': 42520,
#  '박상현': 27695,
#  '지수보이': 42516,
#  '김동준': 20159,
#  '뜨뜨뜨뜨': 24221,
#  '가브리엘': 17298,
#  '미라클': 27127,
#  '섹시피그': 31706,
#  '에스더': 35826,
#  '브렉넥': 29637,
#  '로자르': 24941,
#  '임샤크': 40188,
#  '그라마틱': 19642,
#  '석티비': 31286,
#  '유레카': 38426,
#  '콜드': 44690,
#  '김성태': 20295,
#  '맛종욱': 25858,
#  '김기열': 20113,
#  '릴카': 25409,
#  'ksv': 8184,
#  'ntt': 10207,
#  'c9': 2735,
#  '킴성태': 45139,
#  '10': 35,
#  '모드리뷰': 26408,
#  '모드상황극': 26409,
#  '모드쇼케이스': 26411,
#  '노래': 21724,
#  '로빈': 24907,
#  '로빈유튜브': 24910,
#  '사냥하러': 30342,
#  '갔다가': 17589,
#  '사냥': 30339,
#  '당하는': 22653,
#  '겁나': 18111,
#  '튀어': 45759,
#  'ㅌㅌ': 16670,
#  '주타이쿤': 42157,
#  '16': 229,
#  '동물원': 23625,
#  '꿀잼': 20989,
#  '남자': 21350,
#  '목소리': 26535,
#  '쥬라기크래프트': 42340,
#  'ajehr': 1295,
#  '머독방송': 26047,
#  'dp': 4454,
#  '아이작': 34519,
#  '카스': 44138,
#  '카스온라인': 44139,
#  'ㅁㄷ': 16654,
#  '앙빅': 34980,
#  '머도기': 26044,
#  '영화': 36726,
#  '배틀토이': 28297,
#  '배틀': 28286,
#  '싸움': 33993,
#  '공룡구경': 18814,
#  'bj철구': 2276,
#  '아프리카철구': 34674,
#  'afreecatv': 1230,
#  'bj': 2248,
#  '비제이': 29966,
#  '인터넷방송': 39918,
#  '인터넷방송bj유머방송': 39920,
#  '개그방송': 17799,
#  '유머영상': 38449,
#  '개그영상': 17800,
#  '게임방송': 18142,
#  '웃긴영상': 37988,
#  '웃긴방송': 37980,
#  '선바': 31326,
#  '스트리밍': 33002,
#  '다시보기': 22304,
#  'beryl': 2126,
#  'm762': 8831,
#  '신총': 33746,
#  '혜안': 48633,
#  '랜덤듀오': 24451,
#  '스쿠터': 32781,
#  '퀸톨': 44833,
#  '케이': 44492,
#  '케이tv': 44493,
#  '남캠': 21438,
#  '아프리카': 34660,
#  '개인방송': 17858,
#  '1인방송': 363,
#  '1인미디어': 362,
#  '캠방송': 44325,
#  '토크': 45584,
#  '대세': 22785,
#  '세야': 31631,
#  '봉준': 29086,
#  '와꾸대장봉준': 37436,
#  '기훈': 20034,
#  '킹기훈': 45142,
#  '감스트': 17535,
#  '재밌는영상': 40799,
#  '개그': 17794,
#  '슈기': 32505,
#  '이설': 39296,
#  '엣지': 36092,
#  '여캠': 36327,
#  'eating': 4651,
#  'eatingshow': 4652,
#  '코믹': 44596,
#  '코미디': 44585,
#  '탐방': 45294,
#  '도방': 23370,
#  '여캠탐방': 36328,
#  '섹시여캠': 31701,
#  '청순여캠': 43334,
#  '별풍선': 28793,
#  '겟엠프드': 18186,
#  '고인물': 18602,
#  '장인': 40718,
#  '웃음': 38002,
#  '병맛': 28796,
#  '장난': 40607,
#  '겟엠': 18185,
#  '플레이': 47108,
#  '격투게임': 18215,
#  '마끼아또': 25433,
#  '마끼': 25432,
#  '아또': 34257,
#  '병맛게임': 28797,
#  '웃긴게임': 37972,
#  '웃긴': 37970,
#  '추억의': 43769,
#  '추억': 43767,
#  '찬이': 42999,
#  '엔단': 35976,
#  'tkdghkdrmr': 13918,
#  '강지': 17725,
#  '꽃핀': 20766,
#  '엔찬커플': 36005,
#  '쁘띠허브': 30255,
#  '하이픽셀': 47511,
#  '커플': 44406,
#  '태쁘커플': 45347,
#  '스타': 32823,
#  '빨무': 30164,
#  '깝도이': 20680,
#  'starcraft': 13099,
#  '전략시뮬레이션': 40973,
#  '스타1': 32824,
#  '프로게이머': 46963,
#  '저그': 40870,
#  '테란': 45471,
#  '프로토스': 46999,
#  'yoonroot': 15398,
#  'yr': 15448,
#  '실력파게이머': 33817,
#  '게이머': 18132,
#  '실력': 33815,
#  '에임': 35917,
#  '에임향상': 35918,
#  '배그에임': 28203,
#  '배틀그라운드에임': 28291,
#  '배그프로게이머': 28204,
#  '배틀그라운드프로게이머': 28292,
#  '블루홀': 29789,
#  'fps': 5508,
#  '슈팅게임': 32542,
#  '3인칭슈팅게임': 697,
#  '1인칭슈팅게임': 365,
#  'notitle': 10183,
#  'ksvntt': 8186,
#  'ksvnotitle': 8185,
#  '프로게임단': 46964,
#  '샌드박스네크워크': 30902,
#  '배틀그라운드고인물': 28289,
#  '반동제어': 27896,
#  '배그반동제어': 28195,
#  '배틀그라운드반동제어': 28290,
#  '베릴': 28613,
#  '배그신총': 28198,
#  'berly': 2116,
#  'skt': 12664,
#  't1': 13506,
#  'faker': 5139,
#  'wolf': 15111,
#  'bang': 1897,
#  'untara': 14496,
#  'effort': 4709,
#  'blank': 2312,
#  'thal': 13729,
#  'blossom': 2348,
#  '울프': 37958,
#  '블랭크': 29732,
#  '에포트': 35927,
#  '운타라': 37920,
#  '트할': 45869,
#  '블라썸': 29694,
#  '이상혁': 39277,
#  '꼬마': 20707,
#  '김정균': 20462,
#  '이재완': 39504,
#  '배준식': 28268,
#  '박의진': 27763,
#  '강선구': 17657,
#  '이상호': 39279,
#  '박권혁': 27628,
#  '박범찬': 27668,
#  '잼구': 40857,
#  'lol': 8665,
#  'league': 8394,
#  'of': 10299,
#  'legend': 8429,
#  'champion': 3027,
#  'camera': 2785,
#  '티카': 45979,
#  '티원': 45976,
#  '카메라': 44117,
#  '티캠': 45980,
#  'tcam': 13627,
#  '게임단': 18139,
#  '픽셀건': 47269,
#  '키드': 45044,
#  '무기리뷰': 26639,
#  '무기': 26638,
#  '대리남': 22741,
#  '컨셉건': 44432,
#  '덱추천': 23290,
#  '리니지m': 25180,
#  'ddahyoni': 4004,
#  '따효니': 24117,
#  'hearthstone': 6425,
#  '하스스톤': 47432,
#  'cloud9': 3342,
#  '도적': 23414,
#  '주술사': 42104,
#  '1티어': 379,
#  '기무기훈': 19929,
#  '운고로': 37883,
#  '블리자드': 29794,
#  '룩삼': 25118,
#  '얍얍': 35296,
#  '공혁준': 18932,
#  '철권': 43251,
#  '폴리브릿지': 46783,
#  '윰댕': 38806,
#  'food': 5456,
#  '메이크업': 26206,
#  'makeup': 8901,
#  'make': 8896,
#  'up': 14505,
#  '화장': 48930,
#  '화장품': 48939,
#  'cosmetics': 3600,
#  'korea': 8072,
#  'foodporn': 5458,
#  'overwatch': 10506,
#  'review': 11653,
#  '립스틱': 25413,
#  '틴트': 45995,
#  '향수': 48284,
#  '섀도우': 31060,
#  '덕질': 23117,
#  '직캠': 42658,
#  '라디오': 24239,
#  'radio': 11382,
#  'costume': 3607,
#  '심즈': 33945,
#  '서새봄': 31115,
#  '새봄': 30862,
#  '스팀게임': 33038,
#  'ps4': 11211,
#  'geme': 5766,
#  'afreeca': 1229,
#  '다음팟': 22329,
#  'steamgame': 13134,
#  'twitchtv': 14329,
#  '서농': 31072,
#  '로그라이크': 24828,
#  '사이퍼즈': 30544,
#  '플스4': 47142,
#  '엑스박스': 35969,
#  '엑박': 35943,
#  'xbox': 15214,
#  'rpg': 11903,
#  '알만툴게임': 34910,
#  'iassc': 6901,
#  '바인딩오브아이작': 27602,
#  '이삭의구속': 39259,
#  '아이작리버스': 34520,
#  '아이작애프터버스': 34521,
#  'rebirth': 11520,
#  'afterbirth': 1237,
#  '인디게임': 39785,
#  '액션게임': 35095,
#  '이사만루2018': 39255,
#  '해외': 48125,
#  '네티즌': 21673,
#  '반응': 27925,
#  '월드컵': 38169,
#  '옵드컵': 37412,
#  '2018': 439,
#  '일본': 40043,
#  '한국': 47634,
#  '랩돼': 24469,
#  '모마': 26432,
#  '모두의마블': 26406,
#  'for': 5473,
#  'kakao': 7697,
#  '대리뽑기': 22742,
#  '스케줄': 32766,
#  '4인전': 792,
#  '해스텔': 48118,
#  '해변의에스텔': 48103,
#  '신캐': 33757,
#  '신규캐릭터': 33534,
#  '한정판캐': 47900,
#  '쿠키런': 44786,
#  '오븐브레이크': 37110,
#  '떼탈출': 24172,
#  '타임어택': 45225,
#  '라임맛쿠키': 24376,
#  'cookierun': 3550,
#  'ovenbreak': 10496,
#  '타노스': 45164,
#  '지무비': 42487,
#  '인피니티워': 39967,
#  '어벤져스': 35555,
#  '마블': 25497,
#  '메탈킴': 26247,
#  '게임실황': 18145,
#  '후기': 49141,
#  '게임리뷰': 18141,
#  '게임추천': 18153,
#  '헌터': 48390,
#  '월드': 38162,
#  '멀티': 26104,
#  '매드무비': 25907,
#  '장면': 40652,
#  '재밌는': 40793,
#  '해물': 48089,
#  '파전': 46144,
#  '베스트': 28618,
#  '예능': 36882,
#  '녹화': 21875,
#  '미드': 27101,
#  '해물파전': 48090,
#  '해물파전tv': 48091,
#  'bj해물파전': 2283,
#  '긍정롤세상': 19877,
#  '편집러': 46525,
#  '편집러y': 46526,
#  '자이로센서': 40426,
#  '자이로스코프': 40427,
#  '손캠': 32031,
#  '4핑거': 802,
#  '키보드': 45054,
#  '마우스': 25566,
#  '트리거': 45837,
#  '자극전장': 40307,
#  '한국서버': 47686,
#  '사전예약': 30555,
#  '줄이는법': 42227,
#  '스피드': 33161,
#  '낙하산': 21235,
#  '키실': 45068,
#  '중국서버': 42263,
#  '다운하는법': 22320,
#  '종합': 41984,
#  '심즈4': 33946,
#  '사계절': 30277,
#  '이야기': 39406,
#  'sims4': 12572,
#  'got7': 5991,
#  'mv': 9769,
#  'music': 9737,
#  '뮤직비디오': 26966,
#  '뮤비': 26950,
#  '갓세븐': 17575,
#  'jyp': 7668,
#  '재범': 40806,
#  '제이비': 41556,
#  '진영': 42702,
#  '주니어': 42050,
#  '잭슨': 40853,
#  '영재': 36710,
#  '뱀뱀': 28407,
#  '유겸': 38366,
#  'jb': 7315,
#  'jr': 7564,
#  'mark': 9003,
#  'jackson': 7233,
#  'youngjae': 15424,
#  'bambam': 1882,
#  'yugyeom': 15469,
#  '하지하지마': 47522,
#  '하지': 47519,
#  '하지마': 47520,
#  'stop': 13190,
#  'it': 7189,
#  '2pm': 569,
#  '투피엠': 45746,
#  '준케이': 42210,
#  '닉쿤': 22226,
#  '택연': 45414,
#  '우영': 37831,
#  '준호': 42214,
#  '찬성': 42995,
#  'jun': 7611,
#  'nichkhun': 10066,
#  'taecyeon': 13518,
#  'wooyoung': 15151,
#  'junho': 7626,
#  'chansung': 3054,
#  'hot': 6701,
#  'pink': 10897,
#  'hotpink': 6711,
#  '핫핑크': 48031,
#  '핑크': 47334,
#  'exid': 5034,
#  '이엑스아이디': 39420,
#  '솔지': 32063,
#  '혜린': 48629,
#  '정화': 41448,
#  '하니': 47384,
#  '엘리': 36026,
#  'solji': 12858,
#  'hyelin': 6838,
#  'junghwa': 7618,
#  'hani': 6305,
#  'le': 8390,
#  'ㄷ턍': 16653,
#  'exidhotpink': 5035,
#  'ikon': 6947,
#  '아이콘': 34529,
#  '빅뱅': 30028,
#  '세븐틴': 31614,
#  '싸이': 33996,
#  'psy': 11217,
#  'vixx': 14726,
#  'ken': 7821,
#  '옥택연': 37304,
#  '신사동호랭이': 33635,
#  '예당': 36891,
#  '예당엔터테인먼트': 36892,
#  'pop': 11030,
#  'musical': 9739,
#  'genre': 5780,
#  'dpop': 4458,
#  '디팝': 24060,
#  '드림보컬': 23886,
#  '드림댄스': 23884,
#  'dance': 3885,
#  'studio': 13247,
#  '댄스': 22939,
#  '스튜디오': 32978,
#  '커버댄스': 44383,
#  '댄스커버': 22999,
#  '댄스안무': 22983,
#  '드림댄스학원': 23885,
#  '舞蹈': 17100,
#  '舞蹈翻拍': 17102,
#  '舞蹈教程': 17101,
#  'dream舞蹈学院': 4496,
#  '舞团': 17099,
#  'cover': 3627,
#  'tutorial': 14268,
#  'dream': 4484,
#  'academy': 1113,
#  'tarian': 13603,
#  'remake': 11595,
#  'ダンス': 16453,
#  'ダンスリメイク': 16455,
#  'ダンスチュートリアル': 16454,
#  'ドリームダンスアカデミー': 16502,
#  'nhảy': 10056,
#  'múa': 9823,
#  'lại': 8819,
#  'khiêu': 7873,
#  'vũ': 14808,
#  '트와이스': 45856,
#  'twice': 14320,
#  'ツワイス': 16468,
#  '트둥이': 45770,
#  '우아하게': 37822,
#  'like': 8540,
#  'ooh': 10405,
#  'ahh': 1263,
#  'kt': 8188,
#  'ktmusic': 8192,
#  'yt': 15452,
#  'quality': 11316,
#  'high': 6518,
#  'likey': 8544,
#  '라이키': 24333,
#  'dragon': 4467,
#  'stone': 13187,
#  '스톤': 32973,
#  '커버': 44381,
#  'bts': 2614,
#  'bangtan': 1906,
#  'boys': 2486,
#  'sonyeondan': 12891,
#  'beyond': 2153,
#  'scenes': 12154,
#  '방탄소년단': 28158,
#  'jungkook': 7619,
#  'taehyung': 13521,
#  'jimin': 7417,
#  'hope': 6678,
#  'hoseok': 6692,
#  'rap': 11442,
#  'monster': 9569,
#  'namjoon': 9867,
#  'suga': 13302,
#  'yoongi': 15394,
#  'jin': 7421,
#  'seokjin': 12279,
#  'lyrics': 8812,
#  'hip': 6554,
#  'hop': 6677,
#  'cc': 2943,
#  'eng': 4823,
#  'han': 6276,
#  'rom': 11827,
#  'color': 3422,
#  'coded': 3387,
#  'english': 4828,
#  'hangul': 6302,
#  'romanization': 11836,
#  'dark': 3944,
#  'wild': 15033,
#  'cypher': 3800,
#  'pt3': 11224,
#  'killer': 7913,
#  '2014': 412,
#  '2017': 430,
#  'af': 1218,
#  'supreme': 13392,
#  'boi': 2393,
#  'nct': 9929,
#  'taeyong': 13533,
#  'jaehyun': 7247,
#  'jungwoo': 7624,
#  'kun': 8206,
#  'chenle': 3101,
#  'ten': 13687,
#  'renjun': 11611,
#  'yuta': 15496,
#  'doyoung': 4453,
#  'johnny': 7496,
#  'jaemin': 7251,
#  'jeno': 7357,
#  'lucas': 8767,
#  'winwin': 15076,
#  'jisung': 7439,
#  'taeil': 13522,
#  'haechan': 6227,
#  '태용': 45367,
#  '재현': 40840,
#  '정우': 41320,
#  '천러': 43205,
#  '런쥔': 24605,
#  '유타': 38609,
#  '도영': 23402,
#  '쟈니': 40863,
#  '재민': 40792,
#  '제노': 41496,
#  '루카스': 25094,
#  '윈윈': 38340,
#  '지성': 42512,
#  '태일': 45369,
#  '해찬': 48160,
#  'yearbook': 15305,
#  '엔시티': 35987,
#  '엔이칠': 35998,
#  '엔드림': 35980,
#  ...}

# %%
vect2.transform([train["tag"].loc[0]]).toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
vect2.transform([train["title"].loc[0]]).toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vect2.transform([train["tag"].loc[0]]).toarray(), vect2.transform([train["title"].loc[0]]).toarray())
# Out:
# array([[ 0.4472136]])

# %%
cosine_similarity(vect2.transform([train["tag"].loc[1]]).toarray(), vect2.transform([train["title"].loc[1]]).toarray())
# Out:
# array([[ 0.12943696]])

# %%
cosine_similarity(vect2.transform([train["tag"].loc[2]]).toarray(), vect2.transform([train["title"].loc[2]]).toarray())
# Out:
# array([[ 0.]])

# %%
cosine_similarity(vect2.transform([train["tag"].loc[3]]).toarray(), vect2.transform([train["title"].loc[3]]).toarray())
# Out:
# array([[ 0.45252103]])
